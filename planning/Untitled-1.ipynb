# %%
import os
import socket
import sys

print("Python:", sys.version)
print("Executable:", sys.executable)
print("Hostname:", socket.gethostname())
print("CWD:", os.getcwd())
# Out:
# Python: 3.11.6 | packaged by conda-forge | (main, Oct  3 2023, 10:40:35) [GCC 12.3.0]
# Executable: /opt/conda/bin/python
# Hostname: jupyter-nanihari
# CWD: /home/jovyan

# %%
import subprocess
result = subprocess.run(["sudo", "apt-get", "install", "-y", "firefox"], 
                       capture_output=True, text=True)
print(result.stdout)
print(result.stderr)

# %%
import subprocess
result = subprocess.run(["sudo", "apt-get", "install", "-y", "firefox"], 
                       capture_output=True, text=True)
print(result.stdout)
print(result.stderr)

# %%
import subprocess
result = subprocess.run(["sudo", "apt-get", "install", "-y", "firefox"], 
                       capture_output=True, text=True)
print(result.stdout)
print(result.stderr)

# %%
import subprocess
result = subprocess.run(["sudo", "apt-get", "install", "-y", "firefox"], 
                       capture_output=True, text=True)
print(result.stdout)
print(result.stderr)

# %%
import subprocess
result = subprocess.run(["sudo", "apt-get", "install", "-y", "firefox"], 
                       capture_output=True, text=True)
print(result.stdout)
print(result.stderr)

# %%
import subprocess
result = subprocess.run(["sudo", "apt-get", "install", "-y", "firefox"], 
                       capture_output=True, text=True)
print(result.stdout)
print(result.stderr)import subprocess
result = subprocess.run(["sudo", "apt-get", "install", "-y", "firefox"], 
                       capture_output=True, text=True)
print(result.stdout)
print(result.stderr)import subprocess
result = subprocess.run(["sudo", "apt-get", "install", "-y", "firefox"], 
                       capture_output=True, text=True)
print(result.stdout)
print(result.stderr)

# %%
import importlib.util
import urllib.request

packages = ["numpy", "pandas", "matplotlib", "scikit-learn", "torch", "transformers"]
print("Package availability:")
for name in packages:
    found = importlib.util.find_spec(name) is not None
    print(f"- {name}: {'OK' if found else 'MISSING'}")

print("\nInternet check:")
try:
    with urllib.request.urlopen("https://pypi.org", timeout=10) as resp:
        print("- HTTPS to pypi.org: OK", resp.status)
except Exception as e:
    print("- HTTPS to pypi.org: FAILED", str(e))
# Out:
# Package availability:
# - numpy: OK
# - pandas: OK
# - matplotlib: OK
# - scikit-learn: MISSING
# - torch: MISSING
# - transformers: MISSING
#
# Internet check:
# - HTTPS to pypi.org: OK 200

# %%
import subprocess
import sys

packages_to_install = ["scikit-learn", "torch", "transformers"]

print("Installing missing ML packages...")
for package in packages_to_install:
    print(f"\nInstalling {package}...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", package])
    print(f"✓ {package} installed successfully")

print("\n✅ All packages installed!")
# Out:
# Installing missing ML packages...
#
# Installing scikit-learn...
# ✓ scikit-learn installed successfully
#
# Installing torch...
# ✓ torch installed successfully
#
# Installing transformers...
# ✓ transformers installed successfully
#
# ✅ All packages installed!

# %%
import subprocess
result = subprocess.run(["sudo", "apt-get", "install", "-y", "firefox"], 
                       capture_output=True, text=True)
print(result.stdout)
print(result.stderr)
# Out:
# sudo: The "no new privileges" flag is set, which prevents sudo from running as root.
# sudo: If sudo is running in a container, you may need to adjust the container configuration to disable the flag.
